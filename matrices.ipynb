# %% [markdown]
# <a href="https://colab.research.google.com/github/adavipallimunishankar/data-science/blob/main/matrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numpy as np
